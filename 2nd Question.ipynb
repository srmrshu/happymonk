# %%
pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /Users/shubhamraj/ocr/venv/lib/python3.10/site-packages (6.0)
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the '/Users/shubhamraj/ocr/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.9.3-cp310-cp310-macosx_10_9_x86_64.whl (34.3 MB)
#      |████████████████████████████████| 34.3 MB 8.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in /Users/shubhamraj/ocr/venv/lib/python3.10/site-packages (from scipy) (1.22.3)
# Installing collected packages: scipy
# Successfully installed scipy-1.9.3
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the '/Users/shubhamraj/ocr/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torchvision

import seaborn

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
imgs = ['2.jpeg','3.jpeg','4.jpg']  # batch of images

# # Inference
# results = model(imgs)

# # Results
# results.print()
# results.save()  # or .show()

# results.xyxy[0]  # img1 predictions (tensor)
# results.pandas().xyxy[0]
# Out:
# Using cache found in /Users/shubhamraj/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-10-20 Python-3.10.2 torch-1.12.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
results.print()
# Out:
# image 1/3: 285x474 1 person, 1 car
# image 2/3: 321x474 2 persons, 1 car
# image 3/3: 600x600 1 person, 2 cars
# Speed: 13.5ms pre-process, 318.4ms inference, 2.1ms NMS per image at shape (3, 3, 640, 640)

# %%
results.save()
# Out:
# Saved 3 images to runs/detect/exp7

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=474x285>
# <PIL.Image.Image image mode=RGB size=474x321>
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
results.xyxy[0]
# Out:
# tensor([[190.43893,  34.11235, 474.00000, 260.66882,   0.91906,   0.00000],
#         [  1.33622,  27.74358, 225.36493, 252.93045,   0.79296,   2.00000]])

# %%
results.pandas()
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/3: 285x474 1 person, 1 car
# image 2/3: 321x474 2 persons, 1 car
# image 3/3: 600x600 1 person, 2 cars
# Speed: 13.5ms pre-process, 318.4ms inference, 2.1ms NMS per image at shape (3, 3, 640, 640)

# %%
results.pandas().xyxy[0]
# Out:
#          xmin       ymin        xmax        ymax  confidence  class    name
# 0  190.438934  34.112347  474.000000  260.668823    0.919056      0  person
# 1    1.336224  27.743580  225.364929  252.930450    0.792958      2     car
